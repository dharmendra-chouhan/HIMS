# %% [markdown]
# <a href="https://colab.research.google.com/github/dharmendra-chouhan/HIMS/blob/master/HIMS_08012020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0990cc9c-4569-4610-95a9-6149018bd840" name="files[]" multiple disabled />
#      <output id="result-0990cc9c-4569-4610-95a9-6149018bd840">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HIMS 08-01-2020.csv to HIMS 08-01-2020.csv

# %%
import io
import pandas as pd
revision2014 = pd.read_csv(io.BytesIO(uploaded['HIMS 08-01-2020.csv']))
df1=revision2014

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6736 entries, 0 to 6735
# Data columns (total 4 columns):
# Recorder      6736 non-null object
# Descriptor    6736 non-null object
# Left          6736 non-null object
# Right         1681 non-null object
# dtypes: object(4)
# memory usage: 210.6+ KB

# %%
scriteria = ['SLDC','SDLDC','BACKDOWN','BDN','BACKBOWN','BD','BACKDN','BACK DOWN','B/D','BKD','BKDW','BACKING BOWN','B/DN']  
sstring = '|'.join(scriteria)
df1 =  df1[df1['Descriptor'].str.upper().str.contains(sstring)]
df1=df1.sort_values(by=['Recorder'])

# %%
df1=df1.astype(str)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6736 entries, 4212 to 4125
# Data columns (total 4 columns):
# Recorder      6736 non-null object
# Descriptor    6736 non-null object
# Left          6736 non-null object
# Right         6736 non-null object
# dtypes: object(4)
# memory usage: 263.1+ KB

# %%
import re
import numpy as np

def fu_return_from_to_block(p_text,p_left,p_right):

  # for index1, row in df1.iterrows():
  try:
      text =  p_text
      left =  p_left
      right =  p_right

      list_values=[]
      list_values=text[text.index(left)+len(left):len(text)]
      # print(p_right)
      if len(left)>0 and len(text)>0 and p_right=='NAN':
      # and len(right)==0:
        a=text[text.index(left)+len(left):len(text)]
        if not a:
            from_number=0
            to_number=0
            return from_number,to_number 
        if len(a)>0:
          x=[a]
          res = list(map(lambda sub:int(''.join([ele for ele in sub if ele.isnumeric()])), x))

          if len(str(res[0]))>4:
            from_number=res
            to_number=res

            return from_number,to_number 
          from_number=0
          to_number=0
          if len(str(res[0]))==4:
            from_number=str(res[0])[:2]
            to_number=str(res[0])[-2:]
            # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

            return from_number,to_number 
          elif len(str(res[0]))==3:
            from_number=str(res[0])[:1]
            to_number=str(res[0])[-2:]
            # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

            return from_number,to_number 
          elif len(str(res[0]))==1:
            string = str(res[0])
            if string.isnumeric():
              from_number=str(res[0])[:1]
              to_number=str(res[0])[-1:]
              # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)   

              return from_number,to_number     
          elif (len(str(res[0])))==2:
            z=re.sub('[^A-Za-z0-9--]+', '', list_values)
            if (z.isnumeric()) == True:  
              from_number=str(res[0])[:2]
              to_number=str(res[0])[-2:]
              # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

              return from_number,to_number 
 
            elif  (z.isnumeric()) == False:
              from_number=str(res[0])[:1]
              to_number=str(res[0])[-1:]
              z=""
              a=''
              # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

              return from_number,to_number   
      elif len(right)>0 and len(text)>0 and len(left)>0:

        b=text[text.index(left)+len(left):text.index(right)]
        x=[b]

        res = list(map(lambda sub:int(''.join([ele for ele in sub if ele.isnumeric()])), x))
        if len(str(res[0]))>4:
          from_number=res
          to_number=res

          return from_number,to_number 
        from_number=0
        to_number=0
        if len(str(res[0]))==4:
          from_number=str(res[0])[:2]
          to_number=str(res[0])[-2:]
            # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

          return from_number,to_number 
        elif len(str(res[0]))==3:
          from_number=str(res[0])[:1]
          to_number=str(res[0])[-2:]
            # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

          return from_number,to_number 
        elif len(str(res[0]))==1:
          string = str(res[0])
          if string.isnumeric():
            from_number=str(res[0])[:1]
            to_number=str(res[0])[-1:]
              # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)   

            return from_number,to_number     
        elif (len(str(res[0])))==2:
          t=res[0]
          z=re.sub('[^A-Za-z0-9--]+', '', str(t))
          if (z.isnumeric()) == True:  
            from_number=str(res[0])[:2]
            to_number=str(res[0])[-2:]
              # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

            return from_number,to_number 
 
          elif  (z.isnumeric()) == False:
            from_number=str(res[0])[:1]
            to_number=str(res[0])[-1:]
            z=""
            a=''
              # print(text.ljust(100),str(res).ljust(15),str(from_number).ljust(15),str(to_number).ljust(15) ,str(left).ljust(15)  ,right)

            return from_number,to_number   


      from_number=0
      to_number=0   
  except ValueError:
    # print ('ValueError: could not convert string to float: \'DataCamp\'')
    from_number=0
    to_number=0
    return from_number,to_number  
  else:
    from_number=0
    to_number=0
    return from_number,to_number

# %%
total_count=0
count_leftreghtnull=0
count_wihtprocess=0
print('Recorder'.ljust(35),'Descriptor'.ljust(100), str('From Number').ljust(15),'  -   ','To Number')
print('\n')
for index1, row in df1.iterrows():
    from_number1=0
    to_number1=0
    
    text =  row['Descriptor'].upper()
    left =  row['Left'].upper()
    right =  row['Right'].upper()
         
    # print(text.ljust(100), str(left).ljust(15),'  -   ',right)
    if  (left=='NAN' and right=='NAN'):
      pass
      count_leftreghtnull =count_leftreghtnull+1
    else:
      from_number1,to_number1=fu_return_from_to_block(text,left,right)
      # if from_number1==0 and to_number1==0:
      print(row['Recorder'].ljust(35),text.ljust(130), str(from_number1).ljust(15),'  -   ',to_number1)


      count_wihtprocess=count_wihtprocess+1
    total_count=total_count+1
    from_number1='0'
    to_number1='0'
print("Total :",total_count)
print("Left right Null Values count:",count_leftreghtnull)
print("From and To Number Count:",count_wihtprocess)
# Out:
# Recorder                            Descriptor                                                                                           From Number       -    To Number
#
#
# 010614I1-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I10-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I11-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I12-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I13-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I14-TPC_MSEB-SHIRKE_MSEB      INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I15-MSEB-KSSSK_MSEB           INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I16-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I17-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I18-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I19-MSEB-AAENERGY_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I2-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I20-BEST_MSEB-GEL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I21-BEST_MSEB-MVNL_MSEB       INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I22-BEST_MSEB-LAIL_MSEB       INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I23-MSEB-ASPL_MSEB            INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I24-TPC_MSEB-KOHINOOR_MSEB    INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I25-MSEB-URJANKUR_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I26-MSEB-ULTRATECH_MSEB       INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I27-REL_MSEB-LMEL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I28-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I29-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I3-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I30-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I31-MSEB-WPCL_MSEB            INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I32-REL_MSEB-MSEB             INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I33-TPC_MSEB-MSEB             INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I34-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I35-BEST_MSEB-WELSPUN_MSEB    INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I36-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I37-TPC_MSEB-WPCL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I38-MSEB-JSW_MSEB             INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I39-REL_MSEB-JHPL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I4-TPC_MSEB-MAHATI_MSEB       INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I5-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I6-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I7-BEST_MSEB-YEAL_MSEB        INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I8-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010614I9-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SMOOTHENING AND LMEL SCH UPDATED BY SLDC                                                                0                 -    0
# 010814I1-MSEB-WPCL_MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I1-MSEB-WPCL_MSEB             INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I10-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I10-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I11-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I11-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I12-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I12-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I13-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I13-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I14-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I14-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I16-MSEB-URJANKUR_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I16-MSEB-URJANKUR_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I17-MSEB-UTTAMGLVA_MSEB       INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I17-MSEB-UTTAMGLVA_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I18-MSEB-UTTAMGLVA_MSEB       INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I18-MSEB-UTTAMGLVA_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I19-MSEB-ULTRATECH_MSEB       INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I19-MSEB-ULTRATECH_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I2-MSEB-WPCL_MSEB             INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I2-MSEB-WPCL_MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I20-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I20-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I21-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I21-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I22-MSEB-AAENERGY_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I22-MSEB-AAENERGY_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I23-MSEB-ASPL_MSEB            INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I23-MSEB-ASPL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I24-REL_MSEB-ITC_MSEB         INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I24-REL_MSEB-ITC_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I25-TPC_MSEB-KPC_MSEB         INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I25-TPC_MSEB-KPC_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I26-TPC_MSEB-LMEL_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I26-TPC_MSEB-LMEL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I27-TPC_MSEB-WPCL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I27-TPC_MSEB-WPCL_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I28-TPC_MSEB-MAHATI_MSEB      INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I28-TPC_MSEB-MAHATI_MSEB      INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I29-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I29-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I3-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I3-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I30-BEST_MSEB-YEAL_MSEB       INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I30-BEST_MSEB-YEAL_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I31-BEST_MSEB-GEL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I31-BEST_MSEB-GEL_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I32-BEST_MSEB-MVNL_MSEB       INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I32-BEST_MSEB-MVNL_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I33-BEST_MSEB-LAIL_MSEB       INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I33-BEST_MSEB-LAIL_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I34-BEST_MSEB-WELSPUN_MSEB    INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I34-BEST_MSEB-WELSPUN_MSEB    INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I35-BEST_MSEB-PDL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I35-BEST_MSEB-PDL_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I36-REL_MSEB-MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I36-REL_MSEB-MSEB             INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I37-TPC_MSEB-MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I37-TPC_MSEB-MSEB             INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I38-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I38-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I39-TPC_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I39-TPC_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I4-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I4-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I40-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I40-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I41-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I41-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I42-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I42-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I5-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I5-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I6-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I6-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I7-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I7-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I8-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I8-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 010814I9-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES BY SLDC                                                                      0                 -    0
# 010814I9-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -REV BY SLDC: BD IMP: VIPL AND JSW TO RINFRA DA : BLK[76-96]                                                  76                -    96
# 011214I1-MSEB-WPCL_MSEB             INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I10-MSEB-JSW_MSEB             INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I11-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I12-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I13-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I14-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I15-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I16-MSEB-UTTAMGALVA_MSEB      INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I17-MSEB-UTTAMGALVA_MSEB      INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I18-MSEB-ULTRATECH_MSEB       INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I19-MSEB-AAENERGY_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I2-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I20-MSEB-ASPL_MSEB            INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I21-MSEB-BSISPAT_MSEB         INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I22-TPC_MSEB-WPCL_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I23-BEST_MSEB-GEL_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I24-BEST_MSEB-MVNL_MSEB       INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I25-BEST_MSEB-LAIL_MSEB       INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I26-BEST_MSEB-WELSPUN_MSEB    INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I27-BEST_MSEB-PDL_MSEB        INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I28-BEST_MSEB-YAEL_MSEB       INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I29-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I3-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I30-REL_MSEB-MSEB             INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I31-TPC_MSEB-MSEB             INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I32-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I33-TPC_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I34-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I4-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I5-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I6-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I7-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I8-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 011214I9-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -JSW TO RINFRA(DA) AND TATA(DA) SCH CORRECTED BY SLDC                                                         0                 -    0
# 020514I1-MSEB-UTTAMGALVA_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I10-MSEB-JSW_MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I11-MSEB-JSW_MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I12-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I13-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I14-TPC_MSEB-DHARIWAL_MSEB    INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I15-TPC_MSEB-DHARIWAL_MSEB    INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I16-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I17-MSEB-SSK_MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I18-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I19-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I2-MSEB-UTTAMGALVA_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I20-TPC_MSEB-SHIRKE_MSEB      INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I21-MSEB-KSSSK_MSEB           INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I22-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I23-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I24-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I25-MSEB-AAENERGY_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I26-BEST_MSEB-GEL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I27-BEST_MSEB-MVNL_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I28-BEST_MSEB-LAIL_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I29-MSEB-ASPL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I3-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I30-TPC_MSEB-KOHINOOR_MSEB    INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I31-MSEB-URJANKUR_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I32-MSEB-ASHOK_MSEB           INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I33-MSEB-SASPL_MSEB           INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I34-MSEB-ULTRATECH_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I35-MSEB-URJANKURTATYA_MSEB   INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I36-REL_MSEB-LMEL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I37-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I38-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I39-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I4-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I40-MSEB-WPCL_MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I41-REL_MSEB-MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I42-TPC_MSEB-MSEB             INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I43-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I44-BEST_MSEB-WELSPUN_MSEB    INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I45-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I5-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I6-TPC_MSEB-MAHATI_MSEB       INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I7-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I8-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020514I9-BEST_MSEB-YEAL_MSEB        INTRASTATE_BILATERAL -INTRA_STATE_BILATERAL_SCHEDULES DHARIWAL AND VIPL FOR SMOOTHENING BY SLDC                                    0                 -    0
# 020614I1-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I10-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I11-REL_MSEB-VIPL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I12-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I13-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I14-TPC_MSEB-SHIRKE_MSEB      INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I15-MSEB-KSSSK_MSEB           INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I16-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I17-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I18-MSEB-FINOLEX_MSEB         INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I19-MSEB-AAENERGY_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I2-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I20-BEST_MSEB-GEL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I21-BEST_MSEB-MVNL_MSEB       INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I22-BEST_MSEB-LAIL_MSEB       INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I23-MSEB-ASPL_MSEB            INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I24-TPC_MSEB-KOHINOOR_MSEB    INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I25-MSEB-URJANKUR_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I26-MSEB-ULTRATECH_MSEB       INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I27-REL_MSEB-LMEL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I28-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I29-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I3-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I30-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I31-MSEB-WPCL_MSEB            INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I32-REL_MSEB-MSEB             INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I33-TPC_MSEB-MSEB             INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I34-BEST_MSEB-MSEB            INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I35-BEST_MSEB-WELSPUN_MSEB    INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I36-REL_MSEB-JSW_MSEB         INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I37-TPC_MSEB-WPCL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I38-MSEB-JSW_MSEB             INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I39-REL_MSEB-JHPL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I4-TPC_MSEB-MAHATI_MSEB       INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I5-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I6-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I7-BEST_MSEB-YEAL_MSEB        INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I8-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 020614I9-MSEB-JSW_MSEB              INTRASTATE_BILATERAL -VIPL SCH SMOOOTHEN BY SLDC                                                                                   0                 -    0
# 021014I1-MSEB-WPCL_MSEB             INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I10-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I11-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I12-MSEB-TOPWORTH_MSEB        INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I13-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I14-MSEB-VHPL_MSEB            INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I15-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I16-MSEB-SCML_MSEB            INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# 021014I18-MSEB-URJANKUR_MSEB        INTRASTATE_BILATERAL -REV BY SLDC:JSW TO MSEDCL DA AND MSEDCL: BD IMP: BLK[87-96]                                                  87                -    96
# ...
# W20901F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20902F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20902F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20903F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20903F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20904F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20904F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20905F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20905F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20906F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20906F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20907F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20907F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20908F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20908F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20909F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20909F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20910F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20910F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20911F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20911F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20912F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20912F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20913F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20913F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20914F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20914F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20915F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20915F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20916F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20916F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20917F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20917F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20918F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20918F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20919F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20919F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20920F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20920F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20954F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20954F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20955F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20955F-REL_MSEB-JPL                INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20956F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20956F-REL_MSEB-JPL                INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20957F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20957F-REL_MSEB-JPL                INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20960F-MSEB-JPL                    INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W20960F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W20972F-MSEB-HINDAHEJ_GUVNL         INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W21051F-MSEB-JPL                    INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W21052F-MSEB-APL3_GUVNL             INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W21411DA-MSEB-SEL                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W21415DA-MSEB-SEL                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W21453DA-MSEB-SEL                   INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W21529DA-MSEB-SEL                   INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W21565DA-MSEB-SEL                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W435DA-REL_MSEB-GRIDCO              INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W5889DA-MSEB-APL1                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W5890DA-MSEB-APL2_                  INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W5891DA-MSEB-APL1                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W5892DA-MSEB-APL2_                  INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W705951-MSEB-APL2                   INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W705960DA-MSEB-APL2_                INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W706012DA-MSEB-APL2                 INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W706013DA-MSEB-APL3                 INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W706025DA-MSEB-APL3                 INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W706028DA-MSEB-APL2                 INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# W706040DA-MSEB-APL3                 INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W706041DA-MSEB-APL3                 INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W706042DA-MSEB-APL2                 INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# W706043DA-MSEB-APL2                 INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# WE01DA-MSEB-EPMPL                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# WR0002DA-MSEB-JKHCL                 INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# WR21159DA-MSEB-APNRL                INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# WR261679DA-MSEB-APNRL               INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# WSLMSCS-CSEB-MSEB                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# WSLMSCS-CSEB-MSEB                   INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# WSLMSCS-CSEB-MSEB                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# WWL1421-MSEB-EMCO                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# WWL1421-MSEB-EMCO                   INTERSTATE_BILATERAL -BY SLDC                                                                                                      0                 -    0
# WWL1421-MSEB-EMCO                   INTERSTATE_BILATERAL -INTER_STATE_ BILATERAL_SCHEDULE BY SLDC                                                                      0                 -    0
# Total : 6736
# Left right Null Values count: 0
# From and To Number Count: 6736
